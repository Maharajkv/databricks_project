# %% [markdown]
# # Pratice of databricks
# ### Day to Day tasks and updates
#
# ![K v maharaj](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)
# ### K v **_maharaj_**
# ![]("https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg")

# %% [markdown]
# ## Creating Volume

# %%
# %sql
CREATE VOLUME usage_metrics;

# %%
# %run ./4_child_nb_dataload

# %%
dbutils.fs.ls("/Volumes/workspace/default/volumewd36")

# %%
df1 = spark.read.format("csv").option(
    "header", True
).load("/Volumes/workspace/default/volumewd36/patients.csv")
display(df1)

# %%
df1.write.mode("overwrite").saveAsTable("default.mobile_os_usage")

# %%
display(spark.sql("SELECT * FROM default.mobile_os_usage"))

# %%
def to_upper_case(input_str):
    return input_str.upper()
    print(input_str)
spark.udf.register("to_upper_case", to_upper_case)
spark.sql("SELECT to_upper_case('hello')").show()

# %%
# %pip install pandas

# %%
import pandas as pd

df_pd = pd.read_csv("/Volumes/workspace/default/volumewd36/patients.csv")
display(df_pd)

# %%
# %sh
echo "Magic commands tasks completed"
