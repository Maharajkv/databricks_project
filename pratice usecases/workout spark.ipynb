# %%
df = spark.read.format("csv").option(
    "header", True
).load("/Volumes/workspace/default/volumewd36/patients1.csv")
display(df)

# %%
# %sql
create catalog if not exists catalog1_dropme;
create database if not exists catalog1_dropme.schema1_dropme;
create volume if not exists catalog1_dropme.schema1_dropme.volume1_dropme;

# %%
dbutils.fs.mkdirs("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme")

# %%
# %sql
CREATE CATALOG IF NOT EXISTS workspace;
CREATE DATABASE IF NOT EXISTS workspace.wd36schema2;
CREATE VOLUME IF NOT EXISTS workspace.wd36schema2.volume1;

# %%
dbutils.fs.mkdirs("/Volumes/workspace/wd36schema2/volume1/folder1")

# %%
from pyspark.sql.session import SparkSession
print(spark)
spark1=SparkSession.builder.getOrCreate()
print(spark1)

# %%
csv_df1=spark.read.csv("dbfs:///Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs")
print(csv_df1.printSchema())
display(csv_df1)

# %%
csv_df1 = spark.read.csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs", header=True)
print(csv_df1.printSchema())
display(csv_df1)

csv_df2 = spark.read.csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs").toDF("id", "fname", "lname", "age", "prof")
print(csv_df2.printSchema())
display(csv_df2)

# %%
csv_df1.printSchema()
csv_df2.printSchema()

# %%
csv_df1=spark.read.csv("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs",inferSchema=True).toDF("id","fname","lname","age","prof")
csv_df1.where("id in (4004979,4004981)").show(2)
csv_df1.printSchema()

# %%
csv_df1=spark.read.csv("dbfs:////Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs",header=True,sep='~')
csv_df1.show(2)
csv_df1.printSchema()

# %%
csv_df1=spark.read.csv("dbfs:///Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs",inferSchema=True,header=True,sep='~')
csv_df1.show(2)
csv_df2=spark.read.option("header","True").option("inferSchema","true").option("sep","~").format("csv").load("dbfs:///Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs")
csv_df2.show(2)
csv_df3=spark.read.options(header="True",inferSchema="true",sep="~").format("csv").load("dbfs:///Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs")
csv_df3.show(2)

# %%
csv_df1=spark.read.csv("dbfs:///Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs",inferSchema=True,header=True,sep='~')
csv_df1.show(2)

# %%
csv_df3=spark.read.options(header="True",inferSchema="true",sep="~").format("csv").load("dbfs:///Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs")
csv_df3.show(2)

# %%
csv_df1=spark.read.csv("dbfs:///Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs*",inferSchema=True,header=True,sep='~')
print(csv_df1.count())

# %%
csv_df1=spark.read.csv(path=["dbfs:///Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/cust*","/Volumes/workspace/wd36schema/ingestion_volume/source/custs_1"],inferSchema=True,header=True,sep=',')
print(csv_df1.count())

# %%
from pyspark.sql.utils import AnalysisException

paths = [
    "dbfs:///Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme/custs*"
]

existing_paths = [p for p in paths if dbutils.fs.ls(p.split('*')[0])]

if not existing_paths:
    dbutils.fs.mkdirs("/Volumes/catalog1_dropme/schema1_dropme/volume1_dropme/directory_dropme")
    dbutils.fs.mkdirs("/Volumes/workspace/wd36schema/ingestion_volume/source")

csv_df1 = spark.read.csv(path=existing_paths or paths, inferSchema=True, header=True, sep=',')
print(csv_df1.count())
