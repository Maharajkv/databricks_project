# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.volume_sample;

# %%
df = spark.read.format("csv").options(
    header=True,
    inferSchema=True
).load(
    "/Volumes/workspace/default/volume_sample/source/sample.csv"
)

# %%
# %pip install requests
import requests
url = "https://public.tableau.com/app/sample-data/mobile_os_usage.csv"
response = requests.get(url)
response.raise_for_status()
dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv", response.text, overwrite=True)
dbutils.fs.ls("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")

# %%
dbutils.fs.cp(
    "dbfs:/Volumes/workspace/default/volume_sample/source/patients.csv",
    "dbfs:/Volumes/workspace/default/volumewd36/patients.csv"
)

# %% [markdown]
# ![]("C:\Users\warlo\Downloads\patients.csv")
